# %%
import pandas as pd

# Load each file and check shape
train = pd.read_csv('../data/raw/train.csv')
stores = pd.read_csv('../data/raw/stores.csv')
oil = pd.read_csv('../data/raw/oil.csv')
holidays = pd.read_csv('../data/raw/holidays_events.csv')
transactions = pd.read_csv('../data/raw/transactions.csv')

print(f"Train:        {train.shape}")        # (~3M, 6)
print(f"Stores:       {stores.shape}")       # (54, 5)
print(f"Oil:          {oil.shape}")          # (~1218, 2)
print(f"Holidays:     {holidays.shape}")     # (~350, 6)
print(f"Transactions: {transactions.shape}") # (~83K, 3)

# Preview each
print("\n--- Train ---")
print(train.head())
print(train.dtypes)
print(train.isnull().sum())
# Out:
# Train:        (3000888, 6)
# Stores:       (54, 5)
# Oil:          (1218, 2)
# Holidays:     (350, 6)
# Transactions: (83488, 3)
#
# --- Train ---
#    id        date  store_nbr      family  sales  onpromotion
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0
# 1   1  2013-01-01          1   BABY CARE    0.0            0
# 2   2  2013-01-01          1      BEAUTY    0.0            0
# 3   3  2013-01-01          1   BEVERAGES    0.0            0
# 4   4  2013-01-01          1       BOOKS    0.0            0
# id               int64
# date            object
# store_nbr        int64
# family          object
# sales          float64
# onpromotion      int64
# dtype: object
# id             0
# date           0
# store_nbr      0
# family         0
# sales          0
# onpromotion    0
# dtype: int64
